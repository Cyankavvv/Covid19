# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import requests

# %%
url = 'https://api.covid19api.com/summary'

# %%
r = requests.get(url)

# %%
json = r.json()

# %%
json.keys()
# Out:
# dict_keys(['ID', 'Message', 'Global', 'Countries', 'Date'])

# %%
type(json['Global'])
# Out:
# dict

# %%
type(json['Countries'])
# Out:
# list

# %%
type(json['Date'])
# Out:
# str

# %%
type(json['Countries'][0])
# Out:
# dict

# %%
df = pd.DataFrame(json['Countries'])

# %%
df.head(10)
# Out:
#                                      ID              Country CountryCode  \
# 0  4604975d-7536-4ec7-960d-ba7be71ca66f          Afghanistan          AF
# 1  5155ec4f-d76d-4e70-81ba-842fbddf1063              Albania          AL
# 2  e0adc1da-fd4f-4ef2-9174-07717dde7400              Algeria          DZ
# 3  9d4461c0-af72-4236-9499-cb4b2d27e95a              Andorra          AD
# 4  b0252643-dc27-441b-8043-e50a68863a6a               Angola          AO
# 5  a9c77642-af63-4cf1-ac1f-2222ce6ec39e           Antarctica          AQ
# 6  a54ae023-f5ff-4aae-854e-9d317fb9b6ee  Antigua and Barbuda          AG
# 7  fdbc06aa-d4f2-4266-a762-e401bbe94c2a            Argentina          AR
# 8  ba9b9480-284d-48e5-a3e6-85d08aac812c              Armenia          AM
# 9  c55c5040-6bdc-4ffe-87f2-687af24c8b11            Australia          AU
#
#                   Slug  NewConfirmed  TotalConfirmed  NewDeaths  TotalDeaths  \
# 0          afghanistan             0          209451          0         7896
# ...

# %%
plt.bar(df['Country'][0:10], df['TotalConfirmed'][0:10])
plt.xticks(rotation = 75, size = 14)
plt.grid()

plt.yticks(size = 14)
# Out:
# (array([       0.,  2000000.,  4000000.,  6000000.,  8000000., 10000000.,
#         12000000.]),
#  [Text(0, 0.0, '0.0'),
#   Text(0, 2000000.0, '0.2'),
#   Text(0, 4000000.0, '0.4'),
#   Text(0, 6000000.0, '0.6'),
#   Text(0, 8000000.0, '0.8'),
#   Text(0, 10000000.0, '1.0'),
#   Text(0, 12000000.0, '1.2')])

# %%
df[ df['Country'] == 'Chile']
# Out:
#                                       ID  Country CountryCode     Slug  \
# 21  5fac79f2-f7cf-4a92-990c-f3045843a7c6  Bolivia          BO  bolivia
#
#     NewConfirmed  TotalConfirmed  NewDeaths  TotalDeaths  NewRecovered  \
# 21            90         1194277          0        22365             0
#
#     TotalRecovered                      Date Premium
# 21               0  2023-03-22T16:44:58.349Z      {}

# %%
json
# Out:
# {'ID': '2fe22d2f-175c-496c-a2cb-fbe60d166c77',
#  'Message': '',
#  'Global': {'NewConfirmed': 177325,
#   'TotalConfirmed': 674300771,
#   'NewDeaths': 1319,
#   'TotalDeaths': 6793224,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2023-03-22T16:44:58.349Z'},
#  'Countries': [{'ID': '4604975d-7536-4ec7-960d-ba7be71ca66f',
#    'Country': 'Afghanistan',
#    'CountryCode': 'AF',
#    'Slug': 'afghanistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 209451,
#    'NewDeaths': 0,
#    'TotalDeaths': 7896,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-03-22T16:44:58.349Z',
#    'Premium': {}},
#   {'ID': '5155ec4f-d76d-4e70-81ba-842fbddf1063',
#    'Country': 'Albania',
#    'CountryCode': 'AL',
#    'Slug': 'albania',
#    'NewConfirmed': 14,
#    'TotalConfirmed': 334457,
#    'NewDeaths': 0,
#    'TotalDeaths': 3598,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2023-03-22T16:44:58.349Z',
#    'Premium': {}},
# ...

# %%
json['Global']
# Out:
# {'NewConfirmed': 177325,
#  'TotalConfirmed': 674300771,
#  'NewDeaths': 1319,
#  'TotalDeaths': 6793224,
#  'NewRecovered': 0,
#  'TotalRecovered': 0,
#  'Date': '2023-03-22T16:44:58.349Z'}

# %%
paises = ['Argentina', 'Brazil', 'Bolivia', 'Chile', 'Colombia', 'Peru', 'Paraguay']

# %%
df2 = []
for pais in paises:
    df2 = pd.concat(df2, df[ df['Country'] == pais])

# %%
df2

# %%
plt.bar(df['Country'][0:10], df['TotalConfirmed'][0:10])
plt.xticks(rotation = 75, size = 14)
plt.grid()

plt.yticks(size = 14)
# Out:
# (array([       0.,  2000000.,  4000000.,  6000000.,  8000000., 10000000.,
#         12000000.]),
#  [Text(0, 0.0, '0.0'),
#   Text(0, 2000000.0, '0.2'),
#   Text(0, 4000000.0, '0.4'),
#   Text(0, 6000000.0, '0.6'),
#   Text(0, 8000000.0, '0.8'),
#   Text(0, 10000000.0, '1.0'),
#   Text(0, 12000000.0, '1.2')])
